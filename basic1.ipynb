# %% [markdown]
# <a href="https://colab.research.google.com/github/mwoonkim/big_data_lecture2025/blob/main/basic1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Show current directory

# %%
pwd
# Out:
# '/content'

# %% [markdown]
# binary number calculation

# %%
print(6 & 3)
print(bin(6))
print(bin(3))
bin(6 & 3)

# %%
print(6 | 3)
bin(6 | 3)

# %%
print(6 ^3)
bin(6^3)

# %%
print(~3)
bin(~3)

# %%
print(3<<2)
bin(3<<2)

# %% [markdown]
# Lambda function

# %%
list(map(lambda x: x**2,range(5)))

# %%
from functools import reduce
reduce(lambda x, y : x+y, [0,1,2,3,4,5])

# %%
list(filter(lambda x : x<5, range(10)))

# %% [markdown]
# [list] - 중복 허용, 순서 있음(index#)

# %%
thislist = ["apple", "banana", "cherry", "apple", "cherry"]
list1 = ["abe", 34, True, 40, "male"]
thislist[1] = "blackcurrant"
print(thislist)

# %%
thislist.insert(2, "watermelon")
print(thislist)

# %%
thislist.append("orange")
print(thislist)

# %%
tropical=["mango","pineapple", "papaya"]
thislist.extend(tropical)
print(thislist)

# %%
thislist.remove("blackcurrant")
print(thislist)

# %%
thislist.pop(1)
print(thislist)

# %%
for i in range(len(thislist)):
  print(thislist[i])

# %%
i=0
while i < len(thislist):
  print(thislist[i])
  i = i + 1

# %% [markdown]
# (tuple) - 중복 허용, 순서 있음, **내용 바꿀 수 없음**

# %%
fruits = ("apple", "banana", "cherry")
(green, yellow, red) = fruits
print(green)
print(yellow)
print(red)

# %%
x = ("apple", "banana", "cherry")
print(x)
y = list(x)
y[1] = "kiwi"
x = tuple(y)
print(x)

# %% [markdown]
# {set} - 중복 안됨, 순서 없음

# %%
thisset = {"apple", "banana", "cherry"}
for x in thisset:
  print(x)

thisset.add("orange")
print(thisset)

tropical = {"pineapple", "mange", "papaya"}
thisset.update(tropical)
print(thisset)

thisset.remove("banana")
print(thisset)

# %%
set1 ={"a", "b", "c"}
set2 = {1,2,3}
set3 = set1.union(set2)
print(set3)

set4 = set1 | set2
print(set4)

set1.update(set2)
print(set1)

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}
set3 = set1.intersection(set2)
print(set3)

set4 = set1 & set2
print(set4)

set5 = set1.difference(set2)
print(set5)

set6 = set1.symmetric_difference(set2)
print(set6)

# %% [markdown]
# {dictionary} - key:value

# %%
thisdict ={"brand":"Ford", "model":"Mustang", "year":1964}
print(thisdict["brand"])

x = thisdict.keys()
print(x)

y = thisdict.values()
print(y)

z = thisdict.items()
print(z)

thisdict["year"] = 2018
print(thisdict)

thisdict.update({"year":2020})
print(thisdict)

thisdict["color"] = "red"
print(thisdict)

thisdict.update({"color":"red"})
print(thisdict)

thisdict.pop("model")
print(thisdict)

thisdict.popitem()
print(thisdict)

thisdict.popitem()
print(thisdict)

del thisdict["brand"]
print(thisdict)

# %%
thisdict ={"brand":"Ford", "model":"Mustang", "year":1964}
print(thisdict)

mydict = thisdict.copy()
print(mydict)

mydict = dict(thisdict)
print(mydict)

# %%
myfamily = { "child1":{"name":"Emil", "year":2004}, "child2":{"name":"Tobias", "year":2007}, "child3":{"name":"Linus", "year":2011}}
print(myfamily)

print(myfamily["child2"]["name"])

for x, obj in myfamily.items():
  print(x)

for y in obj:
  print(y + ':', obj[y])

# %% [markdown]
# module

# %%
import math
math.sqrt(2)

# %%
import math as m
m.sqrt(2)

# %%
import calendar
calendar.prmonth(2025,9)

# %%
import datetime as dt
dt.datetime.now()

# %%
import time
time.time()

# %%
import random as rd
rd.random()

# %%
import turtle
turtle.setup(width=400, height=400)
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# /tmp/ipython-input-2125462341.py in <cell line: 0>()
#       1 import turtle
# ----> 2 turtle.setup(width=400, height=400)
#
# /usr/lib/python3.12/turtle.py in setup(width, height, startx, starty)
#
# /usr/lib/python3.12/turtle.py in Screen()
#    3728     else return the existing one."""
#    3729     if Turtle._screen is None:
# -> 3730         Turtle._screen = _Screen()
#    3731     return Turtle._screen
#    3732
#
# /usr/lib/python3.12/turtle.py in __init__(self)
#    3739     def __init__(self):
#    3740         if _Screen._root is None:
# -> 3741             _Screen._root = self._root = _Root()
#    3742             self._root.title(_Screen._title)
#    3743             self._root.ondestroy(self._destroy)
#
# /usr/lib/python3.12/turtle.py in __init__(self)
#     428     """Root class for Screen based on Tkinter."""
# ...

# %%
import sys
sys.prefix

# %% [markdown]
# mymodule.py

# %%
with open('mymodule.py', 'w') as f:
    f.write('def greeting(name):\n')
    f.write('  print("Hello, " + name)\n')

# %%
import mymodule as mym
mym.greeting("Kim")

# %% [markdown]
# try ~ except

# %%
try:
  f = open("demofile.txt")
  try:
    f.write("Lorum Ipsum")
  except:
    print("Something went wrong when writing to the file")
  finally:
    f.close()
except:
  print("Something went wrong when opening the file")

# %%
x = "hello"
if not type(x) is int:
  print(x)

  raise TypeError("Only integers are allowed")

# %% [markdown]
# class

# %%
class Person:
  def __init__(self, name, age):
    self.name = name
    self.age = age

p1 = Person("John", 35)
print(p1.name)
print(p1.age)

print(p1)

# %%
class Person:
  def __init__(self, name, age):
    self.name = name
    self.age = age

  def __str__(self):
    return f"{self.name}({self.age})"

p1 = Person("John", 35)
print(p1)

# %%
class Person:
  def __init__(self, name, age):
    self.name = name
    self.age = age

  def myfunc(self):
    print("Hello my name is " + self.name)

p1 = Person("John", 35)
p1.myfunc()

# %%
p1.age =40
print(p1.age)

# %%
class Person0:
  pass

# %% [markdown]
# array

# %%
import numpy as np
x = np.array(5)
print(x)

y = np.array([1,2,3,4,5])
print(y)

z = np.array([[1,2,3],[4,5,6]])
print(z)

x3 = np.array([[[1,2,3],[4,5,6]],[[1,2,3],[4,5,6]]])
print(x3)

xn = np.array([1,2,3,4], ndmin=5)
print(xn)
print(xn.ndim)

# %% [markdown]
# Basic Stat in python

# %%
import numpy as np
import scipy as sp
from scipy import stats
import pandas as pd
import sklearn
from sklearn.datasets import load_iris

# %%
x = [1,2,10,43,22,87,52,11,8,36]
print(len(x))
print(np.mean(x))
print(np.var(x))
print(np.std(x))
print(np.max(x))
print(np.min(x))
print(np.median(x))
print(np.percentile(x,25))
print(np.percentile(x, 50))
print(np.percentile(x,75))

a = [3,5,8,11,13]
b = [1,2,3,4,5]
np.corrcoef(a,b)

# %%
print(stats.describe(x))

# %%
s = pd.Series(x)
print(s.describe())

# %%
iris=load_iris()
print(iris.keys())
iris['data'][:10]
iris['target'][-10:]
iris['DESCR']
iris['feature_names']
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
iris_df = pd.DataFrame(iris.data, columns = iris.feature_names)
iris_df['species'] = iris.target
display(iris_df.head())
cor_matrix = iris_df.corr(numeric_only = True)
display(cor_matrix)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
ax = sns.heatmap(cor_matrix, annot=True)
ylim = ax.get_ylim()
ax.set_ylim(ylim[0] + 0.5, ylim[1] - 0.5)
plt.show()
